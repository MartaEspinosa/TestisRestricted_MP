# %%
import os,re
import pandas as pd
from collections import Counter
from rna_seq_normalization import Normalization as Norm
from functools import reduce

annot = pd.read_csv("/users/genomics/marta/TestisProject_SaraRazquin/with_TranscriptomeReconstruction/human/newReference_Resconstructed/1transcript_1gene.reconstructed.csv")

# %% [markdown]
# ## Quantify in thymus

# %%
# %%bash
#
# ###PREPARING NEEDED DATA
# thymus_dir=/projects_eg/projects/marta/thymus
# outdir=/users/genomics/marta/TestisProject_SaraRazquin/with_TranscriptomeReconstruction/human/quantification_thymus
#
# mkdir -p $outdir
# AnnotGTF=/users/genomics/marta/TestisProject_SaraRazquin/with_TranscriptomeReconstruction/human/newReference_Resconstructed/gencode.v38.gffcompare.TestisLiverBrain.annotation.sorted.1transcript.sorted.NOchr.gtf
#
# module load Subread/2.0.3
# ########################
#
# # countReadPairs may need to be removed in case of single-end reads
# featureCounts -T 10 -p -s 2 -g transcript_id -O --countReadPairs -a $AnnotGTF -o ${outdir}/gffcompare_stranded_featureCounts.txt $thymus_dir/GSE*/analysis/05_STAR/uniquely_mapped_2pass_BAM_files/*Aligned.sortedByCoord.out.bam
# Out:
#         ==========     _____ _    _ ____  _____  ______          _____
#         =====         / ____| |  | |  _ \|  __ \|  ____|   /\   |  __ \
#           =====      | (___ | |  | | |_) | |__) | |__     /  \  | |  | |
#             ====      \___ \| |  | |  _ <|  _  /|  __|   / /\ \ | |  | |
#               ====    ____) | |__| | |_) | | \ \| |____ / ____ \| |__| |
#         ==========   |_____/ \____/|____/|_|  \_\______/_/    \_\_____/
# 	  v2.0.3
#
# //========================== featureCounts setting ===========================\\
# ||                                                                            ||
# ||             Input files : 30 BAM files                                     ||
# ||                                                                            ||
# ||                           SRR8668611Aligned.sortedByCoord.out.bam          ||
# ||                           SRR8668612Aligned.sortedByCoord.out.bam          ||
# ||                           SRR8668613Aligned.sortedByCoord.out.bam          ||
# ||                           SRR8668614Aligned.sortedByCoord.out.bam          ||
# ||                           SRR8668615Aligned.sortedByCoord.out.bam          ||
# ||                           SRR8668616Aligned.sortedByCoord.out.bam          ||
# ||                           SRR8668617Aligned.sortedByCoord.out.bam          ||
# ||                           SRR8668618Aligned.sortedByCoord.out.bam          ||
# ||                           SRR8668619Aligned.sortedByCoord.out.bam          ||
# ||                           SRR8668620Aligned.sortedByCoord.out.bam          ||
# ||                           SRR8668621Aligned.sortedByCoord.out.bam          ||
# ||                           SRR8668622Aligned.sortedByCoord.out.bam          ||
# ||                           SRR8668623Aligned.sortedByCoord.out.bam          ||
# ||                           SRR8668624Aligned.sortedByCoord.out.bam          ||
# ||                           SRR8668625Aligned.sortedByCoord.out.bam          ||
# ||                           SRR8668626Aligned.sortedByCoord.out.bam          ||
# ||                           SRR8668627Aligned.sortedByCoord.out.bam          ||
# ||                           SRR8668628Aligned.sortedByCoord.out.bam          ||
# ||                           SRR8668629Aligned.sortedByCoord.out.bam          ||
# ||                           SRR8668630Aligned.sortedByCoord.out.bam          ||
# ||                           SRR8668631Aligned.sortedByCoord.out.bam          ||
# ||                           SRR8668632Aligned.sortedByCoord.out.bam          ||
# ||                           SRR8668633Aligned.sortedByCoord.out.bam          ||
# ||                           SRR8668634Aligned.sortedByCoord.out.bam          ||
# ||                           SRR18941362Aligned.sortedByCoord.out.bam         ||
# ||                           SRR18941363Aligned.sortedByCoord.out.bam         ||
# ||                           SRR18941364Aligned.sortedByCoord.out.bam         ||
# ||                           SRR18941365Aligned.sortedByCoord.out.bam         ||
# ||                           SRR18941366Aligned.sortedByCoord.out.bam         ||
# ||                           SRR18941367Aligned.sortedByCoord.out.bam         ||
# ||                                                                            ||
# ||             Output file : gffcompare_stranded_featureCounts.txt            ||
# ||                 Summary : gffcompare_stranded_featureCounts.txt.summary    ||
# ||              Paired-end : yes                                              ||
# ||        Count read pairs : yes                                              ||
# ||              Annotation : gencode.v38.gffcompare.TestisLiverBrain.anno ... ||
# ||      Dir for temp files : /users/genomics/marta/TestisProject_SaraRazq ... ||
# ||                                                                            ||
# ||                 Threads : 10                                               ||
# ||                   Level : meta-feature level                               ||
# ||      Multimapping reads : not counted                                      ||
# || Multi-overlapping reads : counted                                          ||
# ||   Min overlapping bases : 1                                                ||
# ||                                                                            ||
# \\============================================================================//
#
# //================================= Running ==================================\\
# ||                                                                            ||
# || Load annotation file gencode.v38.gffcompare.TestisLiverBrain.annotatio ... ||
# ||    Features : 265746                                                       ||
# ||    Meta-features : 57866                                                   ||
# ||    Chromosomes/contigs : 22                                                ||
# ||                                                                            ||
# || Process BAM file SRR8668611Aligned.sortedByCoord.out.bam...                ||
# ||    Strand specific : reversely stranded                                    ||
# ||    Paired-end reads are included.                                          ||
# ||    Total alignments : 14323394                                             ||
# ||    Successfully assigned alignments : 10350934 (72.3%)                     ||
# ||    Running time : 1.05 minutes                                             ||
# ||                                                                            ||
# || Process BAM file SRR8668612Aligned.sortedByCoord.out.bam...                ||
# ||    Strand specific : reversely stranded                                    ||
# ||    Paired-end reads are included.                                          ||
# ||    Total alignments : 14290397                                             ||
# ||    Successfully assigned alignments : 10331106 (72.3%)                     ||
# ||    Running time : 0.75 minutes                                             ||
# ||                                                                            ||
# || Process BAM file SRR8668613Aligned.sortedByCoord.out.bam...                ||
# ||    Strand specific : reversely stranded                                    ||
# ||    Paired-end reads are included.                                          ||
# ||    Total alignments : 14669485                                             ||
# ||    Successfully assigned alignments : 10602789 (72.3%)                     ||
# ||    Running time : 0.83 minutes                                             ||
# ||                                                                            ||
# || Process BAM file SRR8668614Aligned.sortedByCoord.out.bam...                ||
# ||    Strand specific : reversely stranded                                    ||
# ||    Paired-end reads are included.                                          ||
# ||    Total alignments : 14241669                                             ||
# ||    Successfully assigned alignments : 10299156 (72.3%)                     ||
# ||    Running time : 0.52 minutes                                             ||
# ||                                                                            ||
# || Process BAM file SRR8668615Aligned.sortedByCoord.out.bam...                ||
# ||    Strand specific : reversely stranded                                    ||
# ||    Paired-end reads are included.                                          ||
# ||    Total alignments : 13118328                                             ||
# ||    Successfully assigned alignments : 9461930 (72.1%)                      ||
# ||    Running time : 0.57 minutes                                             ||
# ||                                                                            ||
# || Process BAM file SRR8668616Aligned.sortedByCoord.out.bam...                ||
# ||    Strand specific : reversely stranded                                    ||
# ||    Paired-end reads are included.                                          ||
# ||    Total alignments : 13008581                                             ||
# ||    Successfully assigned alignments : 9384062 (72.1%)                      ||
# ||    Running time : 0.63 minutes                                             ||
# ||                                                                            ||
# || Process BAM file SRR8668617Aligned.sortedByCoord.out.bam...                ||
# ||    Strand specific : reversely stranded                                    ||
# ||    Paired-end reads are included.                                          ||
# ||    Total alignments : 13429055                                             ||
# ||    Successfully assigned alignments : 9690210 (72.2%)                      ||
# ||    Running time : 0.44 minutes                                             ||
# ||                                                                            ||
# || Process BAM file SRR8668618Aligned.sortedByCoord.out.bam...                ||
# ||    Strand specific : reversely stranded                                    ||
# ||    Paired-end reads are included.                                          ||
# ||    Total alignments : 13007491                                             ||
# ||    Successfully assigned alignments : 9386757 (72.2%)                      ||
# ||    Running time : 0.26 minutes                                             ||
# ||                                                                            ||
# || Process BAM file SRR8668619Aligned.sortedByCoord.out.bam...                ||
# ||    Strand specific : reversely stranded                                    ||
# ||    Paired-end reads are included.                                          ||
# ||    Total alignments : 20222557                                             ||
# ||    Successfully assigned alignments : 15444044 (76.4%)                     ||
# ||    Running time : 0.77 minutes                                             ||
# ||                                                                            ||
# || Process BAM file SRR8668620Aligned.sortedByCoord.out.bam...                ||
# ||    Strand specific : reversely stranded                                    ||
# ||    Paired-end reads are included.                                          ||
# ||    Total alignments : 20104349                                             ||
# ||    Successfully assigned alignments : 15359344 (76.4%)                     ||
# ||    Running time : 1.35 minutes                                             ||
# ||                                                                            ||
# || Process BAM file SRR8668621Aligned.sortedByCoord.out.bam...                ||
# ||    Strand specific : reversely stranded                                    ||
# ||    Paired-end reads are included.                                          ||
# ||    Total alignments : 20273457                                             ||
# ||    Successfully assigned alignments : 15484612 (76.4%)                     ||
# ||    Running time : 1.58 minutes                                             ||
# ||                                                                            ||
# || Process BAM file SRR8668622Aligned.sortedByCoord.out.bam...                ||
# ||    Strand specific : reversely stranded                                    ||
# ||    Paired-end reads are included.                                          ||
# ||    Total alignments : 19991944                                             ||
# ||    Successfully assigned alignments : 15271104 (76.4%)                     ||
# ||    Running time : 2.28 minutes                                             ||
# ||                                                                            ||
# || Process BAM file SRR8668623Aligned.sortedByCoord.out.bam...                ||
# ||    Strand specific : reversely stranded                                    ||
# ||    Paired-end reads are included.                                          ||
# ||    Total alignments : 25424739                                             ||
# ||    Successfully assigned alignments : 19967313 (78.5%)                     ||
# ||    Running time : 1.62 minutes                                             ||
# ||                                                                            ||
# || Process BAM file SRR8668624Aligned.sortedByCoord.out.bam...                ||
# ||    Strand specific : reversely stranded                                    ||
# ||    Paired-end reads are included.                                          ||
# ||    Total alignments : 25248963                                             ||
# ||    Successfully assigned alignments : 19832054 (78.5%)                     ||
# ||    Running time : 1.21 minutes                                             ||
# ||                                                                            ||
# || Process BAM file SRR8668625Aligned.sortedByCoord.out.bam...                ||
# ||    Strand specific : reversely stranded                                    ||
# ||    Paired-end reads are included.                                          ||
# ||    Total alignments : 25466756                                             ||
# ||    Successfully assigned alignments : 20007006 (78.6%)                     ||
# ||    Running time : 1.06 minutes                                             ||
# ||                                                                            ||
# || Process BAM file SRR8668626Aligned.sortedByCoord.out.bam...                ||
# ||    Strand specific : reversely stranded                                    ||
# ||    Paired-end reads are included.                                          ||
# ||    Total alignments : 25101355                                             ||
# ||    Successfully assigned alignments : 19717007 (78.5%)                     ||
# ||    Running time : 1.09 minutes                                             ||
# ||                                                                            ||
# || Process BAM file SRR8668627Aligned.sortedByCoord.out.bam...                ||
# ||    Strand specific : reversely stranded                                    ||
# ||    Paired-end reads are included.                                          ||
# ||    Total alignments : 14335170                                             ||
# ||    Successfully assigned alignments : 11394635 (79.5%)                     ||
# ||    Running time : 0.77 minutes                                             ||
# ||                                                                            ||
# || Process BAM file SRR8668628Aligned.sortedByCoord.out.bam...                ||
# ||    Strand specific : reversely stranded                                    ||
# ||    Paired-end reads are included.                                          ||
# ||    Total alignments : 14043222                                             ||
# ||    Successfully assigned alignments : 11163838 (79.5%)                     ||
# ||    Running time : 0.52 minutes                                             ||
# ||                                                                            ||
# || Process BAM file SRR8668629Aligned.sortedByCoord.out.bam...                ||
# ||    Strand specific : reversely stranded                                    ||
# ||    Paired-end reads are included.                                          ||
# ||    Total alignments : 14365008                                             ||
# ||    Successfully assigned alignments : 11422311 (79.5%)                     ||
# ||    Running time : 0.90 minutes                                             ||
# ||                                                                            ||
# || Process BAM file SRR8668630Aligned.sortedByCoord.out.bam...                ||
# ||    Strand specific : reversely stranded                                    ||
# ||    Paired-end reads are included.                                          ||
# ||    Total alignments : 13966065                                             ||
# ||    Successfully assigned alignments : 11103055 (79.5%)                     ||
# ||    Running time : 0.73 minutes                                             ||
# ||                                                                            ||
# || Process BAM file SRR8668631Aligned.sortedByCoord.out.bam...                ||
# ||    Strand specific : reversely stranded                                    ||
# ||    Paired-end reads are included.                                          ||
# ||    Total alignments : 21587241                                             ||
# ||    Successfully assigned alignments : 16936151 (78.5%)                     ||
# ||    Running time : 2.02 minutes                                             ||
# ||                                                                            ||
# || Process BAM file SRR8668632Aligned.sortedByCoord.out.bam...                ||
# ||    Strand specific : reversely stranded                                    ||
# ||    Paired-end reads are included.                                          ||
# ||    Total alignments : 21502897                                             ||
# ||    Successfully assigned alignments : 16874316 (78.5%)                     ||
# ||    Running time : 1.81 minutes                                             ||
# ||                                                                            ||
# || Process BAM file SRR8668633Aligned.sortedByCoord.out.bam...                ||
# ||    Strand specific : reversely stranded                                    ||
# ||    Paired-end reads are included.                                          ||
# ||    Total alignments : 21702446                                             ||
# ||    Successfully assigned alignments : 17030296 (78.5%)                     ||
# ||    Running time : 1.47 minutes                                             ||
# ||                                                                            ||
# || Process BAM file SRR8668634Aligned.sortedByCoord.out.bam...                ||
# ||    Strand specific : reversely stranded                                    ||
# ||    Paired-end reads are included.                                          ||
# ||    Total alignments : 21349413                                             ||
# ||    Successfully assigned alignments : 16752951 (78.5%)                     ||
# ||    Running time : 0.89 minutes                                             ||
# ||                                                                            ||
# || Process BAM file SRR18941362Aligned.sortedByCoord.out.bam...               ||
# ||    Strand specific : reversely stranded                                    ||
# ||    Paired-end reads are included.                                          ||
# ||    Total alignments : 73502276                                             ||
# ||    Successfully assigned alignments : 52256841 (71.1%)                     ||
# ||    Running time : 1.19 minutes                                             ||
# ||                                                                            ||
# || Process BAM file SRR18941363Aligned.sortedByCoord.out.bam...               ||
# ||    Strand specific : reversely stranded                                    ||
# ||    Paired-end reads are included.                                          ||
# ||    Total alignments : 70831124                                             ||
# ||    Successfully assigned alignments : 52567545 (74.2%)                     ||
# ||    Running time : 1.70 minutes                                             ||
# ||                                                                            ||
# || Process BAM file SRR18941364Aligned.sortedByCoord.out.bam...               ||
# ||    Strand specific : reversely stranded                                    ||
# ||    Paired-end reads are included.                                          ||
# ||    Total alignments : 71334282                                             ||
# ||    Successfully assigned alignments : 52077294 (73.0%)                     ||
# ||    Running time : 2.62 minutes                                             ||
# ||                                                                            ||
# || Process BAM file SRR18941365Aligned.sortedByCoord.out.bam...               ||
# ||    Strand specific : reversely stranded                                    ||
# ||    Paired-end reads are included.                                          ||
# ||    Total alignments : 76583894                                             ||
# ||    Successfully assigned alignments : 55929783 (73.0%)                     ||
# ||    Running time : 2.74 minutes                                             ||
# ||                                                                            ||
# || Process BAM file SRR18941366Aligned.sortedByCoord.out.bam...               ||
# ||    Strand specific : reversely stranded                                    ||
# ||    Paired-end reads are included.                                          ||
# ||    Total alignments : 148726438                                            ||
# ||    Successfully assigned alignments : 103458676 (69.6%)                    ||
# ||    Running time : 5.18 minutes                                             ||
# ||                                                                            ||
# || Process BAM file SRR18941367Aligned.sortedByCoord.out.bam...               ||
# ||    Strand specific : reversely stranded                                    ||
# ||    Paired-end reads are included.                                          ||
# ||    Total alignments : 153956013                                            ||
# ||    Successfully assigned alignments : 106610800 (69.2%)                    ||
# ||    Running time : 6.46 minutes                                             ||
# ||                                                                            ||
# || Write the final count table.                                               ||
# || Write the read assignment summary.                                         ||
# ||                                                                            ||
# || Summary of counting results can be found in file "/users/genomics/marta/T  ||
# || estisProject_SaraRazquin/with_TranscriptomeReconstruction/human/quantific  ||
# || ation_thymus/gffcompare_stranded_featureCounts.txt.summary"                ||
# ||                                                                            ||
# \\============================================================================//

# %%
### modify headers
file = "/users/genomics/marta/TestisProject_SaraRazquin/with_TranscriptomeReconstruction/human/quantification_thymus/gffcompare_stranded_featureCounts.txt"

toc = pd.read_csv(file, sep="\t", comment="#")
toc = toc[toc['Geneid'].str.contains('PAR_')==False]
toc['Geneid']=toc['Geneid'].str.split('.').str[0]
toc.rename(columns={'Geneid':'transcript_id'}, inplace=True)

filter_col = [col for col in toc if col.startswith('/')]
for col in filter_col:
    new_col=col.split("Aligned")[0]
    new_col=new_col.split("/")[-1]
    toc.rename(columns={col:new_col}, inplace=True)

length = toc['Length']
genes = toc['transcript_id']
# we are only interested in the columns with counts
counts = toc
counts.drop(["Chr","Start","End","Strand","Length","transcript_id"],axis=1, inplace=True)
# calculate TPMs
tpm_df = Norm.tpm(counts, length)
# add transcript_id and length again
tpms = pd.concat([genes,tpm_df, length], axis=1)
tpms.to_csv("/users/genomics/marta/TestisProject_SaraRazquin/with_TranscriptomeReconstruction/human/quantification_thymus/table_of_counts_TPMs_thymus.csv", index=None)

# %% [markdown]
# ## Candidates

# %%
tumorReact = pd.read_csv("/projects_eg/projects/marta/TestisRestricted_Microproteins_TSA/with_TranscriptomeReconstruction/Q4_TestisRestricted_TumorSpecific/human/TOv3x_5percent_TestisRestrictedGTEx_Translated_Ctypes_log2ratio3xMEAN.csv")
tumorReact_genes = tumorReact[['transcript_id','gene_id','gene_name']]
tumorReact_genes.drop_duplicates(inplace=True)
tumorReact_genes
# Out:
# /tmp/ipykernel_157873/1926467606.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tumorReact_genes.drop_duplicates(inplace=True)
#        transcript_id          gene_id    gene_name
# 0    ENST00000265007  ENSG00000039600        SOX30
# 4    ENST00000247452  ENSG00000046774       MAGEC2
# 11   ENST00000376150  ENSG00000068985        PAGE1
# 14   ENST00000158009  ENSG00000073598        FNDC8
# 22   ENST00000378988  ENSG00000099399       MAGEB2
# ..               ...              ...          ...
# 392   TCONS_00001462      XLOC_001220  XLOC_001220
# 395   TCONS_00001466      XLOC_001230  XLOC_001230
# 404   TCONS_00001617      XLOC_001342  XLOC_001342
# 409   TCONS_00001992      XLOC_001676  XLOC_001676
# 414   TCONS_00002105      XLOC_001725  XLOC_001725
#
# [136 rows x 3 columns]

# %%
tpms_candidates = tpms[tpms['transcript_id'].isin(tumorReact_genes.transcript_id.values.tolist())]
tpms_candidates.drop(["Length"], axis=1, inplace=True)
tpms_candidates.to_csv("/users/genomics/marta/TestisProject_SaraRazquin/with_TranscriptomeReconstruction/human/quantification_thymus/table_of_counts_TPMs_thymus_TOv3xlog2ratio3xmean.csv")

## compute mean, median, max
tpms_candidates['mean'] = tpms_candidates.iloc[:, 1:].mean(axis=1)
tpms_candidates['median'] = tpms_candidates.iloc[:, 1:].median(axis=1)
tpms_candidates['max'] = tpms_candidates.iloc[:, 1:].max(axis=1)

tpms_candidates_thymus = tpms_candidates[['transcript_id','mean','median','max']]
tpms_candidates_thymus = tpms_candidates_thymus.merge(annot, on="transcript_id")
tpms_candidates_thymus.to_csv("/users/genomics/marta/TestisProject_SaraRazquin/with_TranscriptomeReconstruction/human/quantification_thymus/thymus_summary_TOv3xlog2ratio3xmean.csv")
tpms_candidates_thymus
# Out:
# /tmp/ipykernel_157873/2258808333.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tpms_candidates.drop(["Length"], axis=1, inplace=True)
# /tmp/ipykernel_157873/2258808333.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tpms_candidates['mean'] = tpms_candidates.iloc[:, 1:].mean(axis=1)
# /tmp/ipykernel_157873/2258808333.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tpms_candidates['median'] = tpms_candidates.iloc[:, 1:].median(axis=1)
# /tmp/ipykernel_157873/2258808333.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tpms_candidates['max'] = tpms_candidates.iloc[:, 1:].max(axis=1)
#        transcript_id      mean    median       max          gene_id  \
# 0    ENST00000381059  0.161225  0.000000  0.969202  ENSG00000182583
# 1    ENST00000317103  0.072923  0.000000  0.691067  ENSG00000177504
# 2    ENST00000543214  0.056680  0.000000  0.331745  ENSG00000183304
# 3    ENST00000327968  0.000875  0.000000  0.013950  ENSG00000184735
# 4    ENST00000412172  0.000499  0.000000  0.014967  ENSG00000224960
# ..               ...       ...       ...       ...              ...
# 131  ENST00000269881  0.332265  0.111484  2.686197  ENSG00000269058
# 132  ENST00000601693  0.006701  0.000000  0.081271  ENSG00000196350
# 133  ENST00000596209  0.014091  0.011938  0.103742  ENSG00000213973
# 134  ENST00000600766  0.017706  0.000000  0.076942  ENSG00000268696
# 135   TCONS_00001039  1.109857  0.694586  3.012705      XLOC_000930
#
#           gene_type    gene_name
# 0    protein_coding          VCX
# 1    protein_coding         VCX2
# 2    protein_coding        FAM9A
# 3    protein_coding        DDX53
# 4    protein_coding      PPP4R3C
# ..              ...          ...
# 131  protein_coding        CALR3
# 132  protein_coding       ZNF729
# 133  protein_coding        ZNF99
# 134  protein_coding       ZNF723
# 135           novel  XLOC_000930
#
# [136 rows x 7 columns]
