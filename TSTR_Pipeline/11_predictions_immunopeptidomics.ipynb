# %%
import os, re
import pandas as pd

IPdir = "/users/genomics/marta/241205_Immunopeptidomics_HCC"
PREDdir = "/users/genomics/marta/TestisProject_SaraRazquin/with_TranscriptomeReconstruction/v47/cancers/log2ratio3x/cancertypes/netMHCpan/FrequentHLA-I"

# %%
immunopeptidomics_results = pd.read_csv(os.path.join(IPdir,"results/merged/merged_results_HCC_LUNG_Melanoma.csv"))

print(len(set(immunopeptidomics_results.sequence.values.tolist())),"unique hits in TSTR genes with immunopeptidomics data (HCC + lung + melanoma, FDR5%)")
immunopeptidomics_results
# Out:
# 210 unique hits in TSTR genes with immunopeptidomics data (HCC + lung + melanoma, FDR5%)
#         sequence                                         accessions  \
# 0    AEEPVTEAEML                              sp|Q9UBF1|MAGC2_HUMAN
# 1       AEMLGSVV  sp|P43357|MAGA3_HUMAN;sp|P43360|MAGA6_HUMAN;tr...
# 2      AETSKMKVL  sp|O15479|MAGB2_HUMAN;sp|O15481|MAGB4_HUMAN;sp...
# 3      AETSYVKVL  sp|P43355|MAGA1_HUMAN;sp|P43358|MAGA4_HUMAN;sp...
# 4      AFAPFPTQF  ENST00000636096.3:X:+|109|1990:1901:1970|dORF|...
# ..           ...                                                ...
# 236    YNDEDIYLF        sp|Q5TAQ9|DCAF8_HUMAN;sp|A6NGE4|DC8L1_HUMAN
# 237    YNDEDIYLF        sp|Q5TAQ9|DCAF8_HUMAN;sp|A6NGE4|DC8L1_HUMAN
# 238    YNDEDIYLF        sp|Q5TAQ9|DCAF8_HUMAN;sp|A6NGE4|DC8L1_HUMAN
# 239    YPPLHEWVL                              sp|P43357|MAGA3_HUMAN
# 240    YSEKISYVY  sp|Q16384|SSX1_HUMAN;sp|Q7RTT4|SSX8_HUMAN;ENST...
#
#      num_samples_with_hit                       study orfID_TSTR_RiboSeq  \
# 0                       1  Melanoma_MHCquant_Camarena                NaN
# 1                       1  Melanoma_MHCquant_Camarena                NaN
# 2                       1  Melanoma_MHCquant_Camarena                NaN
# 3                       2  Melanoma_MHCquant_Camarena                NaN
# 4                       1  Melanoma_MHCquant_Camarena                NaN
# ..                    ...                         ...                ...
# 236                     1  Melanoma_MHCquant_Camarena                NaN
# 237                     1      Lung_MHCquant_Camarena                NaN
# 238                     1       HCC_MHCquant_Camarena                NaN
# 239                     1  Melanoma_MHCquant_Camarena                NaN
# 240                     1       HCC_MHCquant_Camarena                NaN
#
#     protein_references      gene_name_x gene_name_y     gene_type_x  \
# 0               unique           MAGEC2      MAGEC2  protein_coding
# 1           non-unique           MAGEA3      MAGEA3  protein_coding
# 2           non-unique           MAGEB2      MAGEB2  protein_coding
# 3           non-unique           MAGEA1      MAGEA1  protein_coding
# 4           non-unique  ENSG00000283599  BX276092.9  protein_coding
# ..                 ...              ...         ...             ...
# 236         non-unique          DCAF8L1     DCAF8L1  protein_coding
# 237         non-unique          DCAF8L1     DCAF8L1  protein_coding
# 238         non-unique          DCAF8L1     DCAF8L1  protein_coding
# 239             unique           MAGEA3      MAGEA3  protein_coding
# 240         non-unique             SSX1        SSX1  protein_coding
#
#              gene_id        gene_id.1     n chr  \
# 0    ENSG00000046774  ENSG00000046774  25.0   X
# 1    ENSG00000221867  ENSG00000221867  39.0   X
# 2    ENSG00000099399  ENSG00000099399  19.0   X
# 3    ENSG00000198681  ENSG00000198681  40.0   X
# 4    ENSG00000283599  ENSG00000283599  13.0   X
# ..               ...              ...   ...  ..
# 236  ENSG00000226372  ENSG00000226372   4.0   X
# 237  ENSG00000226372  ENSG00000226372   4.0   X
# 238  ENSG00000226372  ENSG00000226372   4.0   X
# 239  ENSG00000221867  ENSG00000221867  39.0   X
# 240  ENSG00000126752  ENSG00000126752  38.0   X
#
#                            which_ctypes  \
# 0         BLCA,BRCA,LIHC,LUAD,LUSC,PRAD
# 1    BLCA,BRCA,COAD,LIHC,LUAD,LUSC,PRAD
# 2                        BLCA,LIHC,LUSC
# 3              BLCA,BRCA,LIHC,LUAD,LUSC
# 4                             BLCA,LIHC
# ..                                  ...
# 236                                LIHC
# 237                                LIHC
# 238                                LIHC
# 239  BLCA,BRCA,COAD,LIHC,LUAD,LUSC,PRAD
# 240                      BLCA,BRCA,LIHC
#
#                                                  orfID source_literature
# 0                                                  NaN               NaN
# 1                                                  NaN               NaN
# 2    ENST00000378988.5:X:+|4|1607:99:1059|canonical...           IEAtlas
# 3                                                  NaN               NaN
# 4                                                  NaN               NaN
# ..                                                 ...               ...
# 236                                                NaN               NaN
# 237                                                NaN               NaN
# 238                                                NaN               NaN
# 239                                                NaN               NaN
# 240  ENST00000376919.4:X:+|3|1223:62:629|canonical|ATG          deBeijer
#
# [241 rows x 16 columns]

# %%
for file in os.listdir(PREDdir):
    if file.endswith("WBSB.out"):
        print(file.split(".")[0])
        WB = pd.read_csv(os.path.join(PREDdir,file), header=None, sep='\s+')
        WB.drop([0,3,9,4,5,6,7,8,16,17], axis=1, inplace=True)
        WB.columns = ["MHC","Peptide","Identity","Score_EL","%Rank_EL","Score_BA","%Rank_BA","Aff(nM)"]
        print(len(set(WB.Peptide.values.tolist())),"predicted binders in ",file.split(".")[0],"TSTR genes for any common HLA-I allele")
        
        WB_IP = WB[['Peptide']].merge(immunopeptidomics_results[['sequence']], left_on="Peptide", right_on="sequence")
        print(len(set(WB_IP.Peptide.values.tolist())),"overlapping of hits",file.split(".")[0],"TSTR genes for any common HLA-I allele")
# Out:
# Noncodingnonx
# 660 predicted binders in  Noncodingnonx TSTR genes for any common HLA-I allele
# 1 overlapping of hits Noncodingnonx TSTR genes for any common HLA-I allele
# CTx
# 3571 predicted binders in  CTx TSTR genes for any common HLA-I allele
# 87 overlapping of hits CTx TSTR genes for any common HLA-I allele
# altORFs
# 308 predicted binders in  altORFs TSTR genes for any common HLA-I allele
# 0 overlapping of hits altORFs TSTR genes for any common HLA-I allele
# CTnonx
# 7769 predicted binders in  CTnonx TSTR genes for any common HLA-I allele
# 17 overlapping of hits CTnonx TSTR genes for any common HLA-I allele
