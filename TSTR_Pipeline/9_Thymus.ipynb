# %%
import os,re
import pandas as pd
from collections import Counter
from rna_seq_normalization import Normalization as Norm
from functools import reduce

annot = pd.read_csv("/users/genomics/marta/TestisProject_SaraRazquin/with_TranscriptomeReconstruction/v47/human/newReference_Resconstructed/transID_geneID_isoforms_selected.1to1.csv")
Ref_DIR = "/users/genomics/marta/TestisProject_SaraRazquin/with_TranscriptomeReconstruction/v47/human/newReference_Resconstructed"

# %%
# %%bash -s "$Ref_DIR"
#
#
# sed 's/""/"/g' $1/gencode.v47.gffcompare.TestisLiverBrain.annotation.sorted.1transcript.sorted.NOchr.gtf > test.gtf
# sed 's/\(transcript_id "[^"]*\).*/\1"/' test.gtf > $1/gencode.v47.gffcompare.TestisLiverBrain.annotation.sorted.1transcript.sorted.NOchr.fixed.gtf
# rm test.gtf

# %% [markdown]
# ## Quantify in thymus

# %%
# %%bash
#
# ###PREPARING NEEDED DATA
# thymus_dir=/projects_eg/projects/marta/thymus
# outdir=/users/genomics/marta/TestisProject_SaraRazquin/with_TranscriptomeReconstruction/v47/human/quantification_thymus
#
# mkdir -p $outdir
# AnnotGTF=/users/genomics/marta/TestisProject_SaraRazquin/with_TranscriptomeReconstruction/v47/human/newReference_Resconstructed/gencode.v47.gffcompare.TestisLiverBrain.annotation.sorted.1transcript.sorted.NOchr.fixed.gtf
#
# module load Subread/2.0.3
# ########################
#
# # countReadPairs may need to be removed in case of single-end reads
# featureCounts -T 10 -p -s 2 -g transcript_id -O --countReadPairs -a $AnnotGTF -o ${outdir}/gffcompare_stranded_featureCounts.txt $thymus_dir/GSE*/analysis/05_STAR/uniquely_mapped_2pass_BAM_files/*Aligned.sortedByCoord.out.bam
# Out:
#         ==========     _____ _    _ ____  _____  ______          _____
#         =====         / ____| |  | |  _ \|  __ \|  ____|   /\   |  __ \
#           =====      | (___ | |  | | |_) | |__) | |__     /  \  | |  | |
#             ====      \___ \| |  | |  _ <|  _  /|  __|   / /\ \ | |  | |
#               ====    ____) | |__| | |_) | | \ \| |____ / ____ \| |__| |
#         ==========   |_____/ \____/|____/|_|  \_\______/_/    \_\_____/
# 	  v2.0.3
#
# //========================== featureCounts setting ===========================\\
# ||                                                                            ||
# ||             Input files : 30 BAM files                                     ||
# ||                                                                            ||
# ||                           SRR8668611Aligned.sortedByCoord.out.bam          ||
# ||                           SRR8668612Aligned.sortedByCoord.out.bam          ||
# ||                           SRR8668613Aligned.sortedByCoord.out.bam          ||
# ||                           SRR8668614Aligned.sortedByCoord.out.bam          ||
# ||                           SRR8668615Aligned.sortedByCoord.out.bam          ||
# ||                           SRR8668616Aligned.sortedByCoord.out.bam          ||
# ||                           SRR8668617Aligned.sortedByCoord.out.bam          ||
# ||                           SRR8668618Aligned.sortedByCoord.out.bam          ||
# ||                           SRR8668619Aligned.sortedByCoord.out.bam          ||
# ||                           SRR8668620Aligned.sortedByCoord.out.bam          ||
# ||                           SRR8668621Aligned.sortedByCoord.out.bam          ||
# ||                           SRR8668622Aligned.sortedByCoord.out.bam          ||
# ||                           SRR8668623Aligned.sortedByCoord.out.bam          ||
# ||                           SRR8668624Aligned.sortedByCoord.out.bam          ||
# ||                           SRR8668625Aligned.sortedByCoord.out.bam          ||
# ||                           SRR8668626Aligned.sortedByCoord.out.bam          ||
# ||                           SRR8668627Aligned.sortedByCoord.out.bam          ||
# ||                           SRR8668628Aligned.sortedByCoord.out.bam          ||
# ||                           SRR8668629Aligned.sortedByCoord.out.bam          ||
# ||                           SRR8668630Aligned.sortedByCoord.out.bam          ||
# ||                           SRR8668631Aligned.sortedByCoord.out.bam          ||
# ||                           SRR8668632Aligned.sortedByCoord.out.bam          ||
# ||                           SRR8668633Aligned.sortedByCoord.out.bam          ||
# ||                           SRR8668634Aligned.sortedByCoord.out.bam          ||
# ||                           SRR18941362Aligned.sortedByCoord.out.bam         ||
# ||                           SRR18941363Aligned.sortedByCoord.out.bam         ||
# ||                           SRR18941364Aligned.sortedByCoord.out.bam         ||
# ||                           SRR18941365Aligned.sortedByCoord.out.bam         ||
# ||                           SRR18941366Aligned.sortedByCoord.out.bam         ||
# ||                           SRR18941367Aligned.sortedByCoord.out.bam         ||
# ||                                                                            ||
# ||             Output file : gffcompare_stranded_featureCounts.txt            ||
# ||                 Summary : gffcompare_stranded_featureCounts.txt.summary    ||
# ||              Paired-end : yes                                              ||
# ||        Count read pairs : yes                                              ||
# ||              Annotation : gencode.v47.gffcompare.TestisLiverBrain.anno ... ||
# ||      Dir for temp files : /users/genomics/marta/TestisProject_SaraRazq ... ||
# ||                                                                            ||
# ||                 Threads : 10                                               ||
# ||                   Level : meta-feature level                               ||
# ||      Multimapping reads : not counted                                      ||
# || Multi-overlapping reads : counted                                          ||
# ||   Min overlapping bases : 1                                                ||
# ||                                                                            ||
# \\============================================================================//
#
# //================================= Running ==================================\\
# ||                                                                            ||
# || Load annotation file gencode.v47.gffcompare.TestisLiverBrain.annotatio ... ||
# ||    Features : 339928                                                       ||
# ||    Meta-features : 79623                                                   ||
# ||    Chromosomes/contigs : 74                                                ||
# ||                                                                            ||
# || Process BAM file SRR8668611Aligned.sortedByCoord.out.bam...                ||
# ||    Strand specific : reversely stranded                                    ||
# ||    Paired-end reads are included.                                          ||
# ||    Total alignments : 14323394                                             ||
# ||    Successfully assigned alignments : 11345039 (79.2%)                     ||
# ||    Running time : 0.25 minutes                                             ||
# ||                                                                            ||
# || Process BAM file SRR8668612Aligned.sortedByCoord.out.bam...                ||
# ||    Strand specific : reversely stranded                                    ||
# ||    Paired-end reads are included.                                          ||
# ||    Total alignments : 14290397                                             ||
# ||    Successfully assigned alignments : 11326979 (79.3%)                     ||
# ||    Running time : 0.31 minutes                                             ||
# ||                                                                            ||
# || Process BAM file SRR8668613Aligned.sortedByCoord.out.bam...                ||
# ||    Strand specific : reversely stranded                                    ||
# ||    Paired-end reads are included.                                          ||
# ||    Total alignments : 14669485                                             ||
# ||    Successfully assigned alignments : 11624610 (79.2%)                     ||
# ||    Running time : 0.33 minutes                                             ||
# ||                                                                            ||
# || Process BAM file SRR8668614Aligned.sortedByCoord.out.bam...                ||
# ||    Strand specific : reversely stranded                                    ||
# ||    Paired-end reads are included.                                          ||
# ||    Total alignments : 14241669                                             ||
# ||    Successfully assigned alignments : 11289986 (79.3%)                     ||
# ||    Running time : 0.25 minutes                                             ||
# ||                                                                            ||
# || Process BAM file SRR8668615Aligned.sortedByCoord.out.bam...                ||
# ||    Strand specific : reversely stranded                                    ||
# ||    Paired-end reads are included.                                          ||
# ||    Total alignments : 13118328                                             ||
# ||    Successfully assigned alignments : 10315575 (78.6%)                     ||
# ||    Running time : 0.21 minutes                                             ||
# ||                                                                            ||
# || Process BAM file SRR8668616Aligned.sortedByCoord.out.bam...                ||
# ||    Strand specific : reversely stranded                                    ||
# ||    Paired-end reads are included.                                          ||
# ||    Total alignments : 13008581                                             ||
# ||    Successfully assigned alignments : 10231596 (78.7%)                     ||
# ||    Running time : 0.21 minutes                                             ||
# ||                                                                            ||
# || Process BAM file SRR8668617Aligned.sortedByCoord.out.bam...                ||
# ||    Strand specific : reversely stranded                                    ||
# ||    Paired-end reads are included.                                          ||
# ||    Total alignments : 13429055                                             ||
# ||    Successfully assigned alignments : 10565423 (78.7%)                     ||
# ||    Running time : 0.17 minutes                                             ||
# ||                                                                            ||
# || Process BAM file SRR8668618Aligned.sortedByCoord.out.bam...                ||
# ||    Strand specific : reversely stranded                                    ||
# ||    Paired-end reads are included.                                          ||
# ||    Total alignments : 13007491                                             ||
# ||    Successfully assigned alignments : 10234394 (78.7%)                     ||
# ||    Running time : 0.19 minutes                                             ||
# ||                                                                            ||
# || Process BAM file SRR8668619Aligned.sortedByCoord.out.bam...                ||
# ||    Strand specific : reversely stranded                                    ||
# ||    Paired-end reads are included.                                          ||
# ||    Total alignments : 20222557                                             ||
# ||    Successfully assigned alignments : 16774377 (82.9%)                     ||
# ||    Running time : 0.52 minutes                                             ||
# ||                                                                            ||
# || Process BAM file SRR8668620Aligned.sortedByCoord.out.bam...                ||
# ||    Strand specific : reversely stranded                                    ||
# ||    Paired-end reads are included.                                          ||
# ||    Total alignments : 20104349                                             ||
# ||    Successfully assigned alignments : 16690792 (83.0%)                     ||
# ||    Running time : 0.45 minutes                                             ||
# ||                                                                            ||
# || Process BAM file SRR8668621Aligned.sortedByCoord.out.bam...                ||
# ||    Strand specific : reversely stranded                                    ||
# ||    Paired-end reads are included.                                          ||
# ||    Total alignments : 20273457                                             ||
# ||    Successfully assigned alignments : 16827146 (83.0%)                     ||
# ||    Running time : 0.53 minutes                                             ||
# ||                                                                            ||
# || Process BAM file SRR8668622Aligned.sortedByCoord.out.bam...                ||
# ||    Strand specific : reversely stranded                                    ||
# ||    Paired-end reads are included.                                          ||
# ||    Total alignments : 19991944                                             ||
# ||    Successfully assigned alignments : 16589643 (83.0%)                     ||
# ||    Running time : 0.47 minutes                                             ||
# ||                                                                            ||
# || Process BAM file SRR8668623Aligned.sortedByCoord.out.bam...                ||
# ||    Strand specific : reversely stranded                                    ||
# ||    Paired-end reads are included.                                          ||
# ||    Total alignments : 25424739                                             ||
# ||    Successfully assigned alignments : 21714455 (85.4%)                     ||
# ||    Running time : 0.92 minutes                                             ||
# ||                                                                            ||
# || Process BAM file SRR8668624Aligned.sortedByCoord.out.bam...                ||
# ||    Strand specific : reversely stranded                                    ||
# ||    Paired-end reads are included.                                          ||
# ||    Total alignments : 25248963                                             ||
# ||    Successfully assigned alignments : 21577948 (85.5%)                     ||
# ||    Running time : 0.76 minutes                                             ||
# ||                                                                            ||
# || Process BAM file SRR8668625Aligned.sortedByCoord.out.bam...                ||
# ||    Strand specific : reversely stranded                                    ||
# ||    Paired-end reads are included.                                          ||
# ||    Total alignments : 25466756                                             ||
# ||    Successfully assigned alignments : 21766738 (85.5%)                     ||
# ||    Running time : 0.84 minutes                                             ||
# ||                                                                            ||
# || Process BAM file SRR8668626Aligned.sortedByCoord.out.bam...                ||
# ||    Strand specific : reversely stranded                                    ||
# ||    Paired-end reads are included.                                          ||
# ||    Total alignments : 25101355                                             ||
# ||    Successfully assigned alignments : 21446823 (85.4%)                     ||
# ||    Running time : 0.73 minutes                                             ||
# ||                                                                            ||
# || Process BAM file SRR8668627Aligned.sortedByCoord.out.bam...                ||
# ||    Strand specific : reversely stranded                                    ||
# ||    Paired-end reads are included.                                          ||
# ||    Total alignments : 14335170                                             ||
# ||    Successfully assigned alignments : 12463488 (86.9%)                     ||
# ||    Running time : 0.41 minutes                                             ||
# ||                                                                            ||
# || Process BAM file SRR8668628Aligned.sortedByCoord.out.bam...                ||
# ||    Strand specific : reversely stranded                                    ||
# ||    Paired-end reads are included.                                          ||
# ||    Total alignments : 14043222                                             ||
# ||    Successfully assigned alignments : 12213703 (87.0%)                     ||
# ||    Running time : 0.38 minutes                                             ||
# ||                                                                            ||
# || Process BAM file SRR8668629Aligned.sortedByCoord.out.bam...                ||
# ||    Strand specific : reversely stranded                                    ||
# ||    Paired-end reads are included.                                          ||
# ||    Total alignments : 14365008                                             ||
# ||    Successfully assigned alignments : 12497063 (87.0%)                     ||
# ||    Running time : 0.36 minutes                                             ||
# ||                                                                            ||
# || Process BAM file SRR8668630Aligned.sortedByCoord.out.bam...                ||
# ||    Strand specific : reversely stranded                                    ||
# ||    Paired-end reads are included.                                          ||
# ||    Total alignments : 13966065                                             ||
# ||    Successfully assigned alignments : 12146135 (87.0%)                     ||
# ||    Running time : 0.35 minutes                                             ||
# ||                                                                            ||
# || Process BAM file SRR8668631Aligned.sortedByCoord.out.bam...                ||
# ||    Strand specific : reversely stranded                                    ||
# ||    Paired-end reads are included.                                          ||
# ||    Total alignments : 21587241                                             ||
# ||    Successfully assigned alignments : 18501286 (85.7%)                     ||
# ||    Running time : 0.52 minutes                                             ||
# ||                                                                            ||
# || Process BAM file SRR8668632Aligned.sortedByCoord.out.bam...                ||
# ||    Strand specific : reversely stranded                                    ||
# ||    Paired-end reads are included.                                          ||
# ||    Total alignments : 21502897                                             ||
# ||    Successfully assigned alignments : 18440341 (85.8%)                     ||
# ||    Running time : 0.50 minutes                                             ||
# ||                                                                            ||
# || Process BAM file SRR8668633Aligned.sortedByCoord.out.bam...                ||
# ||    Strand specific : reversely stranded                                    ||
# ||    Paired-end reads are included.                                          ||
# ||    Total alignments : 21702446                                             ||
# ||    Successfully assigned alignments : 18615755 (85.8%)                     ||
# ||    Running time : 0.49 minutes                                             ||
# ||                                                                            ||
# || Process BAM file SRR8668634Aligned.sortedByCoord.out.bam...                ||
# ||    Strand specific : reversely stranded                                    ||
# ||    Paired-end reads are included.                                          ||
# ||    Total alignments : 21349413                                             ||
# ||    Successfully assigned alignments : 18304666 (85.7%)                     ||
# ||    Running time : 0.54 minutes                                             ||
# ||                                                                            ||
# || Process BAM file SRR18941362Aligned.sortedByCoord.out.bam...               ||
# ||    Strand specific : reversely stranded                                    ||
# ||    Paired-end reads are included.                                          ||
# ||    Total alignments : 73502276                                             ||
# ||    Successfully assigned alignments : 56820111 (77.3%)                     ||
# ||    Running time : 1.37 minutes                                             ||
# ||                                                                            ||
# || Process BAM file SRR18941363Aligned.sortedByCoord.out.bam...               ||
# ||    Strand specific : reversely stranded                                    ||
# ||    Paired-end reads are included.                                          ||
# ||    Total alignments : 70831124                                             ||
# ||    Successfully assigned alignments : 57649813 (81.4%)                     ||
# ||    Running time : 1.12 minutes                                             ||
# ||                                                                            ||
# || Process BAM file SRR18941364Aligned.sortedByCoord.out.bam...               ||
# ||    Strand specific : reversely stranded                                    ||
# ||    Paired-end reads are included.                                          ||
# ||    Total alignments : 71334282                                             ||
# ||    Successfully assigned alignments : 56832816 (79.7%)                     ||
# ||    Running time : 1.13 minutes                                             ||
# ||                                                                            ||
# || Process BAM file SRR18941365Aligned.sortedByCoord.out.bam...               ||
# ||    Strand specific : reversely stranded                                    ||
# ||    Paired-end reads are included.                                          ||
# ||    Total alignments : 76583894                                             ||
# ||    Successfully assigned alignments : 61306488 (80.1%)                     ||
# ||    Running time : 1.24 minutes                                             ||
# ||                                                                            ||
# || Process BAM file SRR18941366Aligned.sortedByCoord.out.bam...               ||
# ||    Strand specific : reversely stranded                                    ||
# ||    Paired-end reads are included.                                          ||
# ||    Total alignments : 148726438                                            ||
# ||    Successfully assigned alignments : 111758935 (75.1%)                    ||
# ||    Running time : 3.61 minutes                                             ||
# ||                                                                            ||
# || Process BAM file SRR18941367Aligned.sortedByCoord.out.bam...               ||
# ||    Strand specific : reversely stranded                                    ||
# ||    Paired-end reads are included.                                          ||
# ||    Total alignments : 153956013                                            ||
# ||    Successfully assigned alignments : 115324388 (74.9%)                    ||
# ||    Running time : 4.62 minutes                                             ||
# ||                                                                            ||
# || Write the final count table.                                               ||
# || Write the read assignment summary.                                         ||
# ||                                                                            ||
# || Summary of counting results can be found in file "/users/genomics/marta/T  ||
# || estisProject_SaraRazquin/with_TranscriptomeReconstruction/v47/human/quant  ||
# || ification_thymus/gffcompare_stranded_featureCounts.txt.summary"            ||
# ||                                                                            ||
# \\============================================================================//

# %%
### modify headers
file = "/users/genomics/marta/TestisProject_SaraRazquin/with_TranscriptomeReconstruction/v47/human/quantification_thymus/gffcompare_stranded_featureCounts.txt"

toc = pd.read_csv(file, sep="\t", comment="#")
toc = toc[toc['Geneid'].str.contains('PAR_')==False]
toc['Geneid']=toc['Geneid'].str.split('.').str[0]
toc.rename(columns={'Geneid':'transcript_id'}, inplace=True)

filter_col = [col for col in toc if col.startswith('/')]
for col in filter_col:
    new_col=col.split("Aligned")[0]
    new_col=new_col.split("/")[-1]
    toc.rename(columns={col:new_col}, inplace=True)

length = toc['Length']
genes = toc['transcript_id']
# we are only interested in the columns with counts
counts = toc
counts.drop(["Chr","Start","End","Strand","Length","transcript_id"],axis=1, inplace=True)
# calculate TPMs
tpm_df = Norm.tpm(counts, length)
# add transcript_id and length again
tpms = pd.concat([genes,tpm_df, length], axis=1)
tpms.to_csv("/users/genomics/marta/TestisProject_SaraRazquin/with_TranscriptomeReconstruction/v47/human/quantification_thymus/table_of_counts_TPMs_thymus.csv", index=None)

# %% [markdown]
# ## Candidates

# %%
tumorReact = pd.read_csv("/users/genomics/marta/TestisProject_SaraRazquin/with_TranscriptomeReconstruction/v47/cancers/log2ratio3x/cancertypes/TOv3x_5percent_TestisRestrictedGTEx_Translated_Ctypes_log2ratio3xMEANgenes.csv")
tumorReact_genes = tumorReact[['transcript_id','gene_id','gene_name']]
tumorReact_genes.drop_duplicates(inplace=True)
tumorReact_genes
# Out:
# /tmp/ipykernel_2039007/717917834.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tumorReact_genes.drop_duplicates(inplace=True)
#        transcript_id          gene_id        gene_name
# 0    ENST00000247452  ENSG00000046774           MAGEC2
# 1    ENST00000376979  ENSG00000101435            CST9L
# 2    ENST00000375406  ENSG00000117148            ACTL8
# 3    ENST00000376919  ENSG00000126752             SSX1
# 4    ENST00000326279  ENSG00000131914           LIN28A
# ..               ...              ...              ...
# 236  ENST00000600766  ENSG00000268696           ZNF723
# 239  ENST00000622113  ENSG00000274391             TPTE
# 240  ENST00000632600  ENSG00000282815           TEX13C
# 242  ENST00000749288  ENSG00000287164  ENSG00000287164
# 243  ENST00000219301  ENSG00000103023           PRSS54
#
# [136 rows x 3 columns]

# %%
tpms_candidates = tpms[tpms['transcript_id'].isin(tumorReact_genes.transcript_id.values.tolist())]
tpms_candidates.drop(["Length"], axis=1, inplace=True)
tpms_candidates.to_csv("/users/genomics/marta/TestisProject_SaraRazquin/with_TranscriptomeReconstruction/v47/human/quantification_thymus/table_of_counts_TPMs_thymus_TOv3xlog2ratio3xmean.csv")

## compute mean, median, max
tpms_candidates['mean'] = tpms_candidates.iloc[:, 1:].mean(axis=1)
tpms_candidates['median'] = tpms_candidates.iloc[:, 1:].median(axis=1)
tpms_candidates['max'] = tpms_candidates.iloc[:, 1:].max(axis=1)

tpms_candidates_thymus = tpms_candidates[['transcript_id','mean','median','max']]
tpms_candidates_thymus = tpms_candidates_thymus.merge(annot, on="transcript_id")
tpms_candidates_thymus.to_csv("/users/genomics/marta/TestisProject_SaraRazquin/with_TranscriptomeReconstruction/v47/human/quantification_thymus/thymus_summary_TOv3xlog2ratio3xmean.csv")
tpms_candidates_thymus
# Out:
# /tmp/ipykernel_2039007/1848666162.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tpms_candidates.drop(["Length"], axis=1, inplace=True)
# /tmp/ipykernel_2039007/1848666162.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tpms_candidates['mean'] = tpms_candidates.iloc[:, 1:].mean(axis=1)
# /tmp/ipykernel_2039007/1848666162.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tpms_candidates['median'] = tpms_candidates.iloc[:, 1:].median(axis=1)
# /tmp/ipykernel_2039007/1848666162.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tpms_candidates['max'] = tpms_candidates.iloc[:, 1:].max(axis=1)
#        transcript_id      mean    median       max chr          gene_id  \
# 0    ENST00000381089  0.160864  0.106866  0.858360   X  ENSG00000169059
# 1    ENST00000381059  0.140549  0.000000  0.837284   X  ENSG00000182583
# 2    ENST00000317103  0.063568  0.000000  0.602536   X  ENSG00000177504
# 3    ENST00000543214  0.049121  0.000000  0.287587   X  ENSG00000183304
# 4    ENST00000327968  0.000761  0.000000  0.012223   X  ENSG00000184735
# ..               ...       ...       ...       ...  ..              ...
# 131  ENST00000622113  0.009812  0.000000  0.084195  21  ENSG00000274391
# 132  ENST00000400424  0.857918  0.707291  2.370339  21  ENSG00000177398
# 133   TCONS_00000781  0.111709  0.055255  0.688044  21      XLOC_000680
# 134  ENST00000332271  0.286586  0.069442  1.007379  22  ENSG00000184571
# 135  ENST00000569912  0.419595  0.223973  2.425465  22  ENSG00000261202
#
#        gene_name transcript_type       gene_type
# 0          VCX3A  protein_coding  protein_coding
# 1            VCX  protein_coding  protein_coding
# 2           VCX2  protein_coding  protein_coding
# 3          FAM9A  protein_coding  protein_coding
# 4          DDX53  protein_coding  protein_coding
# ..           ...             ...             ...
# 131         TPTE  protein_coding  protein_coding
# 132       UMODL1  protein_coding  protein_coding
# 133  XLOC_000680           novel           novel
# 134       PIWIL3  protein_coding  protein_coding
# 135    TNRC6B-DT          lncRNA          lncRNA
#
# [136 rows x 9 columns]

# %%
tpms_candidates_thymus = pd.read_csv("/users/genomics/marta/TestisProject_SaraRazquin/with_TranscriptomeReconstruction/v47/human/quantification_thymus/thymus_summary_TOv3xlog2ratio3xmean.csv")
tpms_candidates_thymus[tpms_candidates_thymus['mean'] > 1]
# Out:
#      Unnamed: 0    transcript_id       mean     median         max chr  \
# 54           54  ENST00000295453   1.151701   0.664429    7.568078   2
# 102         102  ENST00000377208  11.901478  10.289783   46.226755  13
# 111         111  ENST00000357424   1.166155   0.130044    9.213451  17
# 114         114  ENST00000663592   1.318409   1.195574    3.689594  18
# 122         122  ENST00000636757   1.219491   0.960492    6.377228  19
# 123         123  ENST00000424985  68.006441  47.925253  143.738921  19
#
#              gene_id gene_name transcript_type       gene_type
# 54   ENSG00000163286      ALPG  protein_coding  protein_coding
# 102  ENSG00000152192    POU4F1  protein_coding  protein_coding
# 111  ENSG00000159224       GIP  protein_coding  protein_coding
# 114  ENSG00000267374  MIR924HG          lncRNA          lncRNA
# 122  ENSG00000261341    SMIM47  protein_coding  protein_coding
# 123  ENSG00000180043   GARIN5B  protein_coding  protein_coding
